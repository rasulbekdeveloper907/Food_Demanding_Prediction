# %%
import pandas as pd
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\SML_2_Pr\Log\preprocessing.log"

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',  # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

try:
    logging.info("CSV fayl o'qilmoqda: data_merged.csv")
    df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\SML_2_Pr\Data\raw_data\Merge_meal.csv")
    logging.info(f"Fayl muvaffaqiyatli o'qildi. Satırlar soni: {len(df)} ustunlar soni: {len(df.columns)}")
except Exception as e:
    logging.error(f"CSV faylni o'qishda xatolik: {e}")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       id  week  center_id  meal_id  \
# 0             0           0  1379560     1         55     1885
# 1             1           1  1466964     1         55     1993
# 2             2           2  1346989     1         55     2539
# 3             3           3  1338232     1         55     2139
# 4             4           4  1448490     1         55     2631
#
#    checkout_price  base_price  emailer_for_promotion  homepage_featured  \
# 0          136.83      152.29                      0                  0
# 1          136.83      135.83                      0                  0
# 2          134.86      135.86                      0                  0
# 3          339.50      437.53                      0                  0
# 4          243.50      242.50                      0                  0
#
#    num_orders     category      cuisine
# 0       177.0  Main Course      Chinese
# 1       270.0     Sandwich       Indian
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489121 entries, 0 to 489120
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           489121 non-null  int64
#  1   Unnamed: 0             489121 non-null  int64
#  2   id                     489121 non-null  int64
#  3   week                   489121 non-null  int64
#  4   center_id              489121 non-null  int64
#  5   meal_id                489121 non-null  int64
#  6   checkout_price         489121 non-null  float64
#  7   base_price             489121 non-null  float64
#  8   emailer_for_promotion  489121 non-null  int64
#  9   homepage_featured      489121 non-null  int64
#  10  num_orders             456548 non-null  float64
#  11  category               489121 non-null  object
#  12  cuisine                489121 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 48.5+ MB

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath("../Source"))

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Rasulbek907\Desktop\SML_2_Pr\myvenv\Scripts\python.exe

# %%
from preprocessing import Cleaner, Encoder, Scaler

# %%
cleaner = Cleaner(df)
df = cleaner.tozala().get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489121 entries, 0 to 489120
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           489121 non-null  int64
#  1   Unnamed: 0             489121 non-null  int64
#  2   id                     489121 non-null  int64
#  3   week                   489121 non-null  int64
#  4   center_id              489121 non-null  int64
#  5   meal_id                489121 non-null  int64
#  6   checkout_price         489121 non-null  float64
#  7   base_price             489121 non-null  float64
#  8   emailer_for_promotion  489121 non-null  int64
#  9   homepage_featured      489121 non-null  int64
#  10  num_orders             489121 non-null  float64
#  11  category               489121 non-null  object
#  12  cuisine                489121 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 48.5+ MB

# %%
encoder = Encoder(df)
df = encoder.encodla().get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489121 entries, 0 to 489120
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           489121 non-null  int64
#  1   Unnamed: 0             489121 non-null  int64
#  2   id                     489121 non-null  int64
#  3   week                   489121 non-null  int64
#  4   center_id              489121 non-null  int64
#  5   meal_id                489121 non-null  int64
#  6   checkout_price         489121 non-null  float64
#  7   base_price             489121 non-null  float64
#  8   emailer_for_promotion  489121 non-null  int64
#  9   homepage_featured      489121 non-null  int64
#  10  num_orders             489121 non-null  float64
#  11  category               489121 non-null  int64
#  12  cuisine                489121 non-null  int64
# dtypes: float64(3), int64(10)
# memory usage: 48.5 MB

# %%
scaler = Scaler(df)
df = scaler.scaling_qil().get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489121 entries, 0 to 489120
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           489121 non-null  float64
#  1   Unnamed: 0             489121 non-null  float64
#  2   id                     489121 non-null  float64
#  3   week                   489121 non-null  float64
#  4   center_id              489121 non-null  float64
#  5   meal_id                489121 non-null  float64
#  6   checkout_price         489121 non-null  float64
#  7   base_price             489121 non-null  float64
#  8   emailer_for_promotion  489121 non-null  float64
#  9   homepage_featured      489121 non-null  float64
#  10  num_orders             489121 non-null  float64
#  11  category               489121 non-null  float64
#  12  cuisine                489121 non-null  float64
# dtypes: float64(13)
# memory usage: 48.5 MB

# %%
df.to_csv(r"C:\Users\Rasulbek907\Desktop\SML_2_Pr\Data\data_preprocessing\Preprocessed.csv", index=False)
